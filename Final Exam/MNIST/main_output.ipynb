# %% [markdown]
# <a href="https://colab.research.google.com/github/valazour/Tugas-Machine-Learning/blob/main/main_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python3 code/train.py --seed=0 --trial=1 --kernel_size=5 --epoch=5
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 24, 24]             800
#        BatchNorm2d-2           [-1, 32, 24, 24]              64
#             Conv2d-3           [-1, 64, 20, 20]          51,200
#        BatchNorm2d-4           [-1, 64, 20, 20]             128
#             Conv2d-5           [-1, 96, 16, 16]         153,600
#        BatchNorm2d-6           [-1, 96, 16, 16]             192
#             Conv2d-7          [-1, 128, 12, 12]         307,200
#        BatchNorm2d-8          [-1, 128, 12, 12]             256
#             Conv2d-9            [-1, 160, 8, 8]         512,000
#       BatchNorm2d-10            [-1, 160, 8, 8]             320
#            Linear-11                   [-1, 10]         102,400
#       BatchNorm1d-12                   [-1, 10]              20
# ...
# Total params: 1,128,180
# Trainable params: 1,128,180
# ...

# %%
# !python3 code/test.py  --seed=0 --trial=1 --kernel_size=5 --logdir=temp

# %%
# !python3 code/homo_ensemble.py --kernel_size=5
# Out:
#    1   58    0    0
#    2   58    0    0
#    3   58    0    0
#    4   58    0    0
#    5   58    0    0
#    6   58    0    0
#    7   58    0    0
#    8   58    0    0
#    9   58    0    0
#   10   58    0    0
#   11   58    0    0
#   12   58    0    0
#   13   58    0    0
#   14   58    0    0
#   15   58    0    0
#   16   58    0    0
#   17   58    0    0
#   18   58    0    0
#   19   58    0    0
#   20   58    0    0
#   21   58    0    0
#   22   58    0    0
#   23   58    0    0
#   24   58    0    0
#   25   58    0    0
#   26   58    0    0
#   27   58    0    0
#   28   58    0    0
#   29   58    0    0
#   30   58    0    0
#   31   58    0    0
#   32   58    0    0
#   33   58    0    0
#   34   58    0    0
#   35   58    0    0
#   36   58    0    0
#   37   58    0    0
#   38   58    0    0
#   39   58    0    0
#   40   58    0    0
#   41   58    0    0
#   42   58    0    0
#   43   58    0    0
#   44   58    0    0
#   45   58    0    0
# ...
